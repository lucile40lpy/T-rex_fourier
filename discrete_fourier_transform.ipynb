# %%
import math

# %%
liste_complexes = [complex(0, 1), complex(3, 1)]

# %%
def dft(liste_complexes):
    
    liste_coefs = []
    
    # On boucle sur le nombre de complexes
    for k in range(len(liste_complexes)):
        liste_coefs.append(k)
    
    return liste_coefs
