# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def segment(p1, p2, m):# p1 et p2 pas lise mais complexe
    div = (p2-p1)/m
    points = [0]*(m+1)
    for i in range(m+1):
        points[i]=p1 + i*div
    return points

points = create_segment(complex(2,3),complex(10,4),5)
z = complex(1, 2)
print(z.real)
# Out:
# 1.0

# %%
# show_segment(points)

# %%
def show_figure(liste_points, m):

    for i in range(len(liste_points) - 1):
        x = []
        y = []
        seg = segment(liste_points[i], liste_points[i+1], m)
    
        liste_x = []
        liste_y = []
        for p in seg:
            liste_x.append(p.real)
            liste_y.append(p.imag)

    
        x = np.asarray(liste_x)
        y = np.asarray(liste_y)

        plt.scatter(x, y)

    plt.show()

l = [complex(0, 0), complex(1, 0), complex(1,1), complex(0, 1), complex(0,0)]
show_figure(l, 100)

# %%
# zéro = [complex(2, 0), complex(2, 2), complex(3,2), complex(3, 0), complex(2,0)]
# deux = [complex(0, 2), complex(1, 2), complex(1, 1), complex(0, 1), complex(0, 0), complex(1, 0)]


zéro = [complex(2.25, 0), complex(2.75, 0), complex(3,0.25), complex(3, 1.75), complex(2.75,2), complex(2.25,2), complex(2,1.75), complex(2,0.25), complex(2.25,0)]
deux = [complex(0, 1.5), complex(0, 1.75), complex(0.25, 2), complex(0.5, 2), complex(0.75, 1.75), complex(0.75, 1.5), complex(0.75, 1), complex(0, 0), complex(2.25, 0)]


figure = deux + zéro 
figure += figure[::-1]
figure_norm = []
for fig in figure:
    figure_norm.append(fig/3)
print(figure_norm)
show_figure(figure_norm, 100)
# Out:
# [0.5j, 0.5833333333333334j, (0.08333333333333333+0.6666666666666666j), (0.16666666666666666+0.6666666666666666j), (0.25+0.5833333333333334j), (0.25+0.5j), (0.25+0.3333333333333333j), 0j, (0.75+0j), (0.75+0j), (0.9166666666666666+0j), (1+0.08333333333333333j), (1+0.5833333333333334j), (0.9166666666666666+0.6666666666666666j), (0.75+0.6666666666666666j), (0.6666666666666666+0.5833333333333334j), (0.6666666666666666+0.08333333333333333j), (0.75+0j), (0.75+0j), (0.6666666666666666+0.08333333333333333j), (0.6666666666666666+0.5833333333333334j), (0.75+0.6666666666666666j), (0.9166666666666666+0.6666666666666666j), (1+0.5833333333333334j), (1+0.08333333333333333j), (0.9166666666666666+0j), (0.75+0j), (0.75+0j), 0j, (0.25+0.3333333333333333j), (0.25+0.5j), (0.25+0.5833333333333334j), (0.16666666666666666+0.6666666666666666j), (0.08333333333333333+0.6666666666666666j), 0.5833333333333334j, 0.5j]
